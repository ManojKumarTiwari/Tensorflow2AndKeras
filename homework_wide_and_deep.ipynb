# %% [markdown]
# <a href="https://colab.research.google.com/github/ManojKumarTiwari/Tensorflow2AndKeras/blob/master/homework_wide_and_deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # content
# - try to implement the below wide and deep nn architecture and train it on fetch_california_house dataset provided by sklearn.dataset

# %%
from IPython.display import Image
Image('/content/mls2_1016.png', width=500)
